# %% [markdown]
# ### `Histogram`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("flights")

df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# Grouping data bye year and calculate total passengers
if df['year'].dtype.name == 'category':
    df['year'] = df['year'].astype(int)

# %%
yearly_data = df.groupby('year', as_index=False)['passengers'].sum()

# %%
yearly_data
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.histplot(
    data=yearly_data,
    x='year',
    weights='passengers',
    # bins=bin_edges,
    bins='auto',
    discrete=True,
    kde=True,
    color='green',
)

plt.gca().lines[0].set_color('darkblue')
plt.gca().lines[0].set_linewidth(3)       
plt.gca().lines[0].set_linestyle('--')    

plt.title('Total Passengers per Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Passengers', fontsize=12)

plt.show()
